# %%
print("Downloads\\Hello World")
# Out:
# Downloads\Hello World

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
orders = pd.read_excel('C:\\Users\\Lenovo\\Downloads\\Retail_dataset.xlsx',sheet_name = 2)

# %%
orders.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_timestamp order_estimated_delivery_date
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2018-08-07 15:27:45                    2018-08-13
# ...

# %%
order_items = pd.read_excel('C:\\Users\\Lenovo\\Downloads\\Retail_dataset.xlsx',sheet_name = 3)

# %%
order_items.head(5)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    shipping_charges
# 0             13.29
# 1             19.93
# 2             17.87
# 3             12.79
# 4             18.14

# %%
payments = pd.read_excel('C:\\Users\\Lenovo\\Downloads\\Retail_dataset.xlsx',sheet_name = 5)

# %%
payments.head(5)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
products = pd.read_excel('C:\\Users\\Lenovo\\Downloads\\Retail_dataset.xlsx',sheet_name = 6)

# %%
products.head(5)
# Out:
#                          product_id product_category_name  product_weight_g  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumery             225.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f                   art            1000.0
# 2  96bd76ec8810374ed1b65e291975717f        sports_leisure             154.0
# 3  cef67bcfe19066a932b7673e239eb23d                  baby             371.0
# 4  9dc1a7de274444849c219cff195d0b71            housewares             625.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               16.0               10.0              14.0
# 1               30.0               18.0              20.0
# 2               18.0                9.0              15.0
# 3               26.0                4.0              26.0
# 4               20.0               17.0              13.0

# %%
customers = pd.read_excel('C:\\Users\\Lenovo\\Downloads\\Retail_dataset.xlsx',sheet_name = 4)

# %%
customers.head(5)
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3  259dac757896d24d7702b9acbbff3f3c                      8775
# 4  345ecd01c38d18a9036ed96c73b8d066                     13056
#
#            customer_city customer_state
# 0                 franca             SP
# 1  sao bernardo do campo             SP
# 2              sao paulo             SP
# 3        mogi das cruzes             SP
# 4               campinas             SP

# %%
df1 = pd.merge( order_items, orders, how='inner', on='order_id')

# %%
df1.head(5)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    shipping_charges                       customer_id order_status  \
# 0             13.29  871766c5855e863f6eccc05f988b23cb    delivered
# ...

# %%
df2 = pd.merge( df1, payments, how='inner', on='order_id')

# %%
df2.head(5)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    shipping_charges                       customer_id order_status  \
# 0             13.29  871766c5855e863f6eccc05f988b23cb    delivered
# ...

# %%
df3 =  pd.merge( df2 , products, how='inner', on='product_id')

# %%
df3.head(5)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
# 3  6f8c31653edb8c83e1a739408b5ff750              1
# 4  7d19f4ef4d04461989632411b7e588b9              1
#
#                          product_id                         seller_id  price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   55.9
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   64.9
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
#
#    shipping_charges                       customer_id order_status  \
# 0             13.29  871766c5855e863f6eccc05f988b23cb    delivered
# ...

# %%
df = pd.merge( df3 , customers, how='inner', on='customer_id')

# %%
df.head(5)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
# 3  6f8c31653edb8c83e1a739408b5ff750              1
# 4  7d19f4ef4d04461989632411b7e588b9              1
#
#                          product_id                         seller_id  price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   55.9
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   64.9
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.9
#
#    shipping_charges                       customer_id order_status  \
# 0             13.29  871766c5855e863f6eccc05f988b23cb    delivered
# ...

# %%
df.shape
# Out:
# (127595, 24)

# %% [raw]
# df.describe()

# %%
df.describe()
# Out:
#        order_item_id          price  shipping_charges  \
# count  127595.000000  127595.000000     127595.000000
# mean        1.204961     119.159236         19.945079
# min         1.000000       0.850000          0.000000
# 25%         1.000000      39.900000         13.010000
# 50%         1.000000      73.500000         16.250000
# 75%         1.000000     131.990000         21.150000
# max        21.000000    6735.000000        409.680000
# std         0.712918     181.395192         15.673361
#
#             order_purchase_timestamp              order_approved_at  \
# count                         127595                         127579
# mean   2017-12-28 20:21:12.510819328  2017-12-29 07:45:07.114823168
# min              2016-09-04 21:15:19            2016-10-04 09:43:32
# 25%              2017-09-08 16:38:16     2017-09-09 11:42:53.500000
# 50%              2018-01-16 14:56:56            2018-01-16 21:11:16
# ...

# %%
df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 127590  ffea406a848c8afe4dec22bf6290ba00              1
# 127591  ffebd80e3291e811c308365936897efd              1
# 127592  fff7c4452f050315db1b3f24d9df5fcd              1
# 127593  fffa82886406ccf10c7b4e35c4ff2788              1
# 127594  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (118322, 24)

# %%
df = df.loc[df.order_status == 'delivered']

# %%
df.shape
# Out:
# (115736, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115736 entries, 0 to 127594
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115736 non-null  object
#  1   order_item_id                  115736 non-null  int64
#  2   product_id                     115736 non-null  object
#  3   seller_id                      115736 non-null  object
#  4   price                          115736 non-null  float64
#  5   shipping_charges               115736 non-null  float64
#  6   customer_id                    115736 non-null  object
#  7   order_status                   115736 non-null  object
#  8   order_purchase_timestamp       115736 non-null  datetime64[ns]
#  9   order_approved_at              115721 non-null  datetime64[ns]
#  10  order_delivered_timestamp      115728 non-null  datetime64[ns]
# ...

# %%
df.isnull().sum()
# Out:
# order_id                           0
# order_item_id                      0
# product_id                         0
# seller_id                          0
# price                              0
# shipping_charges                   0
# customer_id                        0
# order_status                       0
# order_purchase_timestamp           0
# order_approved_at                 15
# order_delivered_timestamp          8
# order_estimated_delivery_date      0
# payment_sequential                 0
# payment_type                       0
# payment_installments               0
# payment_value                      0
# product_category_name            411
# product_weight_g                  20
# product_length_cm                 20
# product_height_cm                 20
# product_width_cm                  20
# customer_zip_code_prefix           0
# customer_city                      0
# customer_state                     0
# dtype: int64

# %%
df = df.drop(columns = ['product_weight_g','product_width_cm','product_length_cm','product_height_cm'])
df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 127590  ffea406a848c8afe4dec22bf6290ba00              1
# 127591  ffebd80e3291e811c308365936897efd              1
# 127592  fff7c4452f050315db1b3f24d9df5fcd              1
# 127593  fffa82886406ccf10c7b4e35c4ff2788              1
# 127594  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
df.isnull().sum()
# Out:
# order_id                           0
# order_item_id                      0
# product_id                         0
# seller_id                          0
# price                              0
# shipping_charges                   0
# customer_id                        0
# order_status                       0
# order_purchase_timestamp           0
# order_approved_at                 15
# order_delivered_timestamp          8
# order_estimated_delivery_date      0
# payment_sequential                 0
# payment_type                       0
# payment_installments               0
# payment_value                      0
# product_category_name            411
# customer_zip_code_prefix           0
# customer_city                      0
# customer_state                     0
# dtype: int64

# %%
df.product_category_name.value_counts(normalize = True)
# Out:
# product_category_name
# toys                                 0.753479
# health_beauty                        0.026525
# bed_bath_table                       0.023568
# sports_leisure                       0.020343
# furniture_decor                      0.019233
#                                        ...
# fashion_childrens_clothes            0.000017
# home_comfort_2                       0.000009
# furniture_mattress_and_upholstery    0.000009
# security_and_services                0.000009
# diapers_and_hygiene                  0.000009
# Name: proportion, Length: 70, dtype: float64

# %%
product_category = df.product_category_name.mode()[0]

# %%
df.product_category_name.fillna(product_category,inplace= True)

# %%
df.product_category_name.isnull().sum()
# Out:
# 0

# %%
df.order_approved_at.value_counts()
# Out:
# order_approved_at
# 2017-08-08 20:43:31    63
# 2017-09-25 17:44:41    38
# 2017-06-09 16:15:08    26
# 2018-02-21 12:28:15    24
# 2017-07-07 15:10:17    24
#                        ..
# 2018-06-14 10:41:46     1
# 2018-06-19 09:36:47     1
# 2018-04-24 17:46:08     1
# 2018-04-07 18:47:52     1
# 2018-06-09 17:10:13     1
# Name: count, Length: 88273, dtype: int64

# %%
df.order_approved_at.dropna()
# Out:
# 0        2017-09-13 09:45:35
# 1        2017-06-29 02:44:11
# 2        2018-05-18 12:31:43
# 3        2017-08-01 18:55:08
# 4        2017-08-10 22:05:11
#                  ...
# 127590   2017-03-15 17:16:36
# 127591   2018-07-13 20:23:55
# 127592   2017-06-01 17:05:23
# 127593   2017-12-18 17:33:04
# 127594   2018-06-09 17:10:13
# Name: order_approved_at, Length: 115721, dtype: datetime64[ns]

# %%
df.order_approved_at.loc.isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.order_approved_at.loc.isnull()
#
# AttributeError: '_LocIndexer' object has no attribute 'isnull'

# %%
df.isnull().sum()
# Out:
# order_id                          0
# order_item_id                     0
# product_id                        0
# seller_id                         0
# price                             0
# shipping_charges                  0
# customer_id                       0
# order_status                      0
# order_purchase_timestamp          0
# order_approved_at                15
# order_delivered_timestamp         8
# order_estimated_delivery_date     0
# payment_sequential                0
# payment_type                      0
# payment_installments              0
# payment_value                     0
# product_category_name             0
# customer_zip_code_prefix          0
# customer_city                     0
# customer_state                    0
# dtype: int64

# %%
df.drop(columns = ['order_approved_at','order_delivered_timestamp'])
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 127590  ffea406a848c8afe4dec22bf6290ba00              1
# 127591  ffebd80e3291e811c308365936897efd              1
# 127592  fff7c4452f050315db1b3f24d9df5fcd              1
# 127593  fffa82886406ccf10c7b4e35c4ff2788              1
# 127594  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
df.shape
# Out:
# (115736, 20)

# %%
df.describe()
# Out:
#        order_item_id          price  shipping_charges  \
# count  115736.000000  115736.000000     115736.000000
# mean        1.197035     119.999611         19.988030
# min         1.000000       0.850000          0.000000
# 25%         1.000000      39.900000         13.080000
# 50%         1.000000      74.900000         16.280000
# 75%         1.000000     133.000000         21.170000
# max        21.000000    6735.000000        409.680000
# std         0.700831     182.694629         15.731081
#
#             order_purchase_timestamp              order_approved_at  \
# count                         115736                         115721
# mean   2017-12-31 16:46:48.868580096  2018-01-01 04:12:14.001512448
# min              2016-10-03 09:44:50            2016-10-04 09:43:32
# 25%              2017-09-12 22:03:44            2017-09-13 14:35:20
# 50%              2018-01-19 09:04:24            2018-01-19 16:06:30
# ...

# %%
df.order_item_id.value_counts()
# Out:
# order_item_id
# 1     101338
# 2      10142
# 3       2357
# 4        967
# 5        455
# 6        257
# 7         62
# 8         37
# 9         29
# 10        26
# 11        17
# 12        13
# 13         8
# 14         7
# 15         5
# 16         3
# 17         3
# 18         3
# 19         3
# 20         3
# 21         1
# Name: count, dtype: int64

# %%
df.to_excel("C:\\Users\\Lenovo\\Downloads\\Capstone.xlsx")
